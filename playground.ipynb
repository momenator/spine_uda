# %%
import torch
import torch.nn as nn

# %%
import os
print(os.listdir('./results/'))
# Out:
# ['unet_wavelet_plain', 'plain_unet_sobel', 'exp12_unet_ssl', 'final_fda_03', 'unet_sobel_adabn_20_batch', 'unet_eadan_bn', 'swd_w_adabn', 'unet_sobel_swd_eadan_in', 'testing', 'mcd_induced_exp4', 'shape_induced_mcd_baseline', 'exp17_unet_dsbn2_ssl', 'mcd_induced_w_decay_exp5', 'plain_unet_dann_batchnorm', 'plain_swd_batchnorm', 'unet_sobel_mcd_eadan_in', 'unet_eadan_in', 'test_2', 'unet_sobel_eadan_in_symmetric_lovasz', 'unet_dan_adabn', 'shape_model_exp1', 'unet_mcd_eadan_in', 'unet_sobel_swd_eadan_in_2_no_reduce', 'unet_sobel_batchnorm', 'shape_induced_dsbn_wasserstein_exp2', 'unet_ssl_unetwavelet', 'dsbn_final', 'exp1_plain_unet_batchnorm', 'test_shape_induced_exp1', '.ipynb_checkpoints', 'unet_sobel_adabn', 'test', 'exp13_unet_bn_ssl', 'exp16_unet_dsin_with_stats_ssl', 'shape_model_exp4', 'unet_shape_aware', 'unet_sobel_swd_eadan_in_20_batch_20_epochs', 'unet_dense_ssl_pretraining', 'exp5_wct2_sparsest_unet_instancenorm', 'plain_sliced_mcd_final', 'shape_induced_exp2', 'shape_mod
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

res1 = np.load('./results/exp1_plain_unet_batchnorm/params.npz')
res2 = np.load('./results/exp2_plain_unet_instancenorm/params.npz')
res3 = np.load('./results/exp3_plain_unet_batchnorm_no_affine/params.npz')
res4 = np.load('./results/exp4_wct2_six_unet_instancenorm/params.npz')
res5 = np.load('./results/exp5_wct2_sparsest_unet_instancenorm/params.npz')
res6 = np.load('./results/exp6_wct2_gan_unet_instancenorm/params.npz')
res7 = np.load('./results/exp7_unet_wavelet_instancenorm/params.npz')
res8 = np.load('./results/exp8_unet_mcd/params.npz')
res9 = np.load('./results/exp9_unet_fda/params.npz')
res10 = np.load('./results/exp10_unet_sobel/params.npz')
res11 = np.load('./results/exp11_unet_sobel_entropy/params.npz')
res12 = np.load('./results/exp12_unet_ssl/params.npz')
res13 = np.load('./results/exp13_unet_bn_ssl/params.npz')
res14 = np.load('./results/exp14_unet_dsbn_ssl/params.npz')
res15 = np.load('./results/exp15_unet_dsin_ssl/params.npz')
res16 = np.load('./results/exp16_unet_dsin_with_stats_ssl/params.npz')
res17 = np.load('./results/exp17_unet_dsbn2_ssl/params.npz')
res_dann = np.load('./results/unet_dann/params.npz')
res_sa = np.load('./results/unet_shape_aware/params.npz')
res_shape_model_exp1 = np.load('./results/shape_model_exp1/params.npz')
res_shape_model_exp2 = np.load('./results/shape_model_exp2/params.npz')
res_shape_model_exp3 = np.load('./results/shape_model_exp3/params.npz')
res_shape_model_exp4 = np.load('./results/shape_model_exp4/params.npz')
res_test_shape_induced_exp1 = np.load('./results/test_shape_induced_exp1/params.npz')
res_test_shape_induced_exp2 = np.load('./results/shape_induced_exp2/params.npz')

res_testing = np.load('./results/shape_induced_dsbn_wasserstein_exp2/params.npz')
res_finetune = np.load('./results/test_2/params.npz')

res_final1 = np.load('./results/mcd_ssl_exp1/params.npz')
res_final2 = np.load('./results/mcd_ssl_augment_exp2/params.npz')
res_final3 = np.load('./results/mcd_ssl_exp3/params.npz')
res_final4 = np.load('./results/mcd_entropy_exp1/params.npz')
res_final5 = np.load('./results/mcd_sobel_exp2/params.npz')

my_res = np.load('./results/final_fda_batchnorm/params.npz')
my_res2 = np.load('./thesis_results/plain_unet_augmentation/params.npz')
my_res3 = np.load('./thesis_results/dense_unet/params.npz')
my_res4 = np.load('./results/unet_wavelet_plain/params.npz')

# plt.plot(my_res['val_dice_a'], label="#1")
# plt.plot(my_res2['val_dice_a'], label="#2")
# plt.plot(my_res3['val_dice_a'], label="#3")
# plt.plot(my_res4['val_dice_a'], label="#4")

# plt.plot(my_res['val_dice_b'], label="exp1 dice B")

# plt.plot(res2['val_dice_a'], label="exp2 dice A")
# plt.plot(res2['val_dice_b'], label="exp2 dice B")

# plt.plot(res3['val_dice_a'], label="exp3 dice A")
# plt.plot(res3['val_dice_b'], label="exp3 dice B")

#plt.plot(res1['val_dice_a'], label="#1 val CT dice")
# plt.plot(my_res['train_dice'], label="#2 train CT dice")
plt.plot(my_res['val_dice_b'], label="#2 val CT dice")

# plt.plot(my_res['net_val_dice_b'], label="#2 val MR dice")

# plt.plot(my_res2['val_dice_a'], label="#3 val CT dice")
# plt.plot(my_res3['val_dice_a'], label="#4 val CT dice")
# plt.plot(my_res4['val_dice_a'], label="#5 val CT dice")


# plt.plot(res1['val_dice_b'], label="exp4 dice B")

# plt.plot(res5['val_dice_a'], label="exp5 dice A")
# plt.plot(res5['val_dice_b'], label="exp5 dice B")

# plt.plot(res6['val_dice_a'], label="exp6 dice A")
# plt.plot(res6['val_dice_b'], label="exp6 dice B")

# plt.plot(res1['val_dice_a'], label="exp7 dice A")
# plt.plot(res1['val_dice_b'], label="exp7 dice B")

# plt.plot(res8['val_dice_a'], label="exp8 dice A")
# plt.plot(res8['val_dice_b'], label="exp8 dice B")

# plt.plot(res9['val_dice_a'], label="exp9 dice A")
# plt.plot(res9['val_dice_b'], label="exp9 dice B")

# plt.plot(res10['val_dice_a'], label="exp10 dice A")
# plt.plot(res10['val_dice_b'], label="exp10 dice B")

# plt.plot(res11['val_dice_a'], label="exp11 dice A")
# plt.plot(res11['val_dice_b'], label="exp11 dice B")

# plt.plot(res12['val_dice_a'], label="exp12 dice A")
# plt.plot(res12['val_dice_b'], label="exp12 dice B")

# plt.plot(res13['val_dice_a'], label="exp13 dice A")
# plt.plot(res13['val_dice_b'], label="exp13 dice B")

# plt.plot(res14['val_dice_a'], label="exp14 dice A")
# plt.plot(res14['val_dice_b'], label="exp14 dice B")

# plt.plot(res15['val_dice_a'], label="exp15 dice A")
# plt.plot(res15['val_dice_b'], label="exp15 dice B")

# plt.plot(res16['val_dice_a'], label="exp16 dice A")
# plt.plot(res16['val_dice_b'], label="exp16 dice B")

plt.title('Avg DSC vs epochs')
# plt.ylim((0.5, 1))
plt.ylabel('DSC')
plt.xlabel('epochs')
# plt.legend(bbox_to_anchor=(1.01, 1.01))
plt.legend()
plt.show()

# %%
# Plot results for initial study here
# 1 - results/exp1_plain_unet_batchnorm
# 2 - thesis_results/plain_unet_2
# 3 - thesis_results/plain_unet_augmentation
# 4 - thesis_results/dense_unet
# 5 - results/unet_wavelet_plain (may change)

res_final1 = np.load('./results/exp1_plain_unet_batchnorm/params.npz')
res_final2 = np.load('./thesis_results/plain_unet_2/params.npz')
res_final3 = np.load('./thesis_results/plain_unet_augmentation/params.npz')
res_final4 = np.load('./thesis_results/dense_unet/params.npz')
res_final5 = np.load('./results/unet_wavelet_final_50_epochs/params.npz')


plt.plot(res_final1['val_loss_a'], label="#1 val CT loss")
plt.plot(res_final2['val_loss_a'], label="#2 val CT loss")
plt.plot(res_final3['val_loss_a'], label="#3 val CT loss")
plt.plot(res_final4['val_loss_a'], label="#4 val CT loss")
plt.plot(res_final5['val_loss_a'], label="#5 val CT loss")


plt.title('Avg loss vs epochs')
# plt.ylim((0.5, 1))
plt.ylabel('Avg loss')
plt.xlabel('epochs')
# plt.legend(bbox_to_anchor=(1.01, 1.01))
plt.legend()
plt.show()

# %%
plt.plot(res_final1['val_dice_a'], label="#1 val CT dice")
plt.plot(res_final2['val_dice_a'], label="#2 val CT dice")
plt.plot(res_final3['val_dice_a'], label="#3 val CT dice")
plt.plot(res_final4['val_dice_a'], label="#4 val CT dice")
plt.plot(res_final5['val_dice_a'], label="#5 val CT dice")


plt.title('Avg DSC vs epochs')
# plt.ylim((0.5, 1))
plt.ylabel('Avg DSC')
plt.xlabel('epochs')
# plt.legend(bbox_to_anchor=(1.01, 1.01))
plt.legend()
plt.show()

# %%
# my_res = np.load('./thesis_results/plain_unet_2/params.npz')

# my_res = res_testing

# print(my_res['epochs'])
for k in my_res:
    print(k)

print(my_res['batch_size'])
# Out:
# num_train
# num_val
# num_test
# epochs
# learning_rate
# batch_size
# val_dice_a
# val_dice_b
# val_loss_a
# val_loss_b
# test_dice_a
# test_dice_b
# test_loss_a
# test_loss_b
# 20

# %%
print(res_final5['net_test_dice_b'])
print(res_final3['netds_test_dice_b'])

print(res_final3['epochs_mcd'])
print(res_final3['num_train'])

print(res_final3['net_test_dice_a'])
print(res_final3['netds_test_dice_a'])

# print(res_testing['pre_ssl_dice'])
# print(res_testing['pre_ssl_dice_gold'])
# print(res_testing['final_dice'])
# print(res_testing['final_dice_gold'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-cc1656669da0> in <module>
# ----> 1 print(res_final5['net_test_dice_b'])
#       2 print(res_final3['netds_test_dice_b'])
#       3
#       4 print(res_final3['epochs_mcd'])
#       5 print(res_final3['num_train'])
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     264                 return self.zip.read(key)
#     265         else:
# --> 266             raise KeyError("%s is not a file in the archive" % key)
#     267
#     268
#
# KeyError: 'net_test_dice_b is not a file in the archive'

# %%
plt.plot(my_res['val_dice_b'], label="net dice B")
# plt.plot(res_final3['netds_val_dice_a'], label="net_ds dice A")

plt.plot(my_res['val_loss_b'], label="net loss B")
# plt.plot(res_testing['parent_val_b_dice'], label="exp1 parent dice B")


plt.ylabel('dice')
plt.xlabel('epochs')
plt.legend(bbox_to_anchor=(1.05, 1.05))
plt.show()

# %%
# plt.plot(res10['val_dice_a'], label="exp10 dice A")
# plt.plot(res10['val_dice_b'], label="exp10 dice B")

plt.plot(res_shape_model_exp1['pseudo_val_a_dice'], label="exp1 dice A")
plt.plot(res_shape_model_exp2['pseudo_val_a_dice'], label="exp2 dice A")
plt.plot(res_shape_model_exp3['pseudo_val_a_dice'], label="exp3 dice A")
plt.plot(res_shape_model_exp4['pseudo_val_a_dice'], label="exp4 dice A")

print(res_shape_model_exp2['project_description'])

plt.ylabel('dice')
plt.xlabel('epochs')
plt.legend(bbox_to_anchor=(1.05, 1.05))
plt.show()
# Out:
# testing shape model (UNetDense) network with heavy corruption for 50 epochs

# %%
print(res10['test_dice_a'], res10['test_dice_b'])
# plt.plot(res10['val_dice_a'], label="10 dice A")
# plt.plot(res10['val_dice_b'], label="10 dice B")
# # plt.title('Plain UNet with instance norm and no affine params')
# plt.plot(res11['val_dice_a'], label="11 dice A")
# plt.plot(res11['val_dice_b'], label="11 dice B")

plt.plot(res10['val_dice_a'], label="10 dice A")
plt.plot(res10['val_dice_b'], label="10 dice B")

# plt.plot(res9['val_dice_a'], label="9 dice A")
# plt.plot(res9['val_dice_b'], label="9 dice B")

# plt.plot(res14['val_dice_a'], label="14 dice A")
# plt.plot(res14['val_dice_b'], label="14 dice B")

# plt.plot(res15['val_dice_a'], label="15 dice A")
# plt.plot(res15['val_dice_b'], label="15 dice B")

# plt.plot(res16['val_dice_a'], label="16 dice A")
# plt.plot(res16['val_dice_b'], label="16 dice B")

# plt.plot(res17['val_dice_a'], label="17 dice A")
# plt.plot(res17['val_dice_b'], label="17 dice B")


plt.ylabel('dice')
plt.xlabel('epochs')
plt.legend(bbox_to_anchor=(1.005, 1.005))
plt.show()
# Out:
# 0.8675350952028917 0.3543335911931888

# %%
# for k in res18:
#     print(k)

plt.plot(res1['val_dice_a'], label="plain unet dice A")
plt.plot(res1['val_dice_b'], label="plain unet dice B")

plt.plot(res2['val_dice_a'], label="instance norm dice A")
plt.plot(res2['val_dice_b'], label="instance norm dice B")

plt.plot(res3['val_dice_a'], label="batch norm dice A")
plt.plot(res3['val_dice_b'], label="batch norm dice B")

plt.ylabel('dice')
plt.xlabel('epochs')
plt.legend(bbox_to_anchor=(1.005, 1.005))
plt.show()

# %%
import torch
from models.modules import conv_bn


conv = conv_bn(64, 64, 5, 1, 2)

test = torch.rand((2, 64, 256, 256))

print(test.size())

out = conv(test)

print(out.size())

print(torch.cat([test, out], dim=1).size())
# Out:
# torch.Size([2, 64, 256, 256])
# torch.Size([2, 64, 256, 256])
# torch.Size([2, 128, 256, 256])

# %%
from models.wct2 import WCT2Features

test = torch.rand((2, 3, 256, 256)).cuda()

net = WCT2Features(None, './wct2_weights/wave_encoder_cat5_l4.pth', './wct2_weights/wave_decoder_cat5_l4.pth')

out = net(test)

print(out.size())
# Out:
# torch.Size([2, 64, 256, 256])

# %%
import numpy as np
from sklearn.metrics import classification_report

a = np.random.randint(0,2, (5,5))
b = np.random.randint(0,2, (5,5))

res = classification_report(a, b, labels=[0,1],target_names=['background', 'foreground'])
print(res)
# Out:
#               precision    recall  f1-score   support
#
#   background       1.00      0.67      0.80         3
#   foreground       0.75      0.75      0.75         4
#
#    micro avg       0.83      0.71      0.77         7
#    macro avg       0.88      0.71      0.78         7
# weighted avg       0.86      0.71      0.77         7
#  samples avg       0.70      0.70      0.67         7
